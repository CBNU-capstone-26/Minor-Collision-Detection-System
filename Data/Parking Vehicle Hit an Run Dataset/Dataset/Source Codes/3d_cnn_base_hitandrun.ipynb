# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# ==========================================
# [파라미터 사용자 설정]
# 실행 환경에 맞게 이 셀의 값만 수정하세요.
# ==========================================

# ---------- 공통 설정 ----------
DATASET_DOWNLOAD_DIR = Path("/content/drive/MyDrive/capstone-26")  # Kaggle 데이터셋을 다운로드/압축 해제할 폴더 경로
DATA_DIR = Path("/content/drive/MyDrive/Dataset/Dataset")  # 학습/평가에 사용할 mp4, txt 데이터 폴더 경로
MODEL_NUM_CLASSES = 2  # 분류할 클래스 수: 0=정상, 1=충돌
CLIP_LENGTH = 30  # 3D-CNN에 입력할 클립 길이(프레임 수)
RESIZE = (224, 224)  # 모델 입력용 프레임 크기(width, height)
R_VALUE = 1.0  # 차량 bbox 주변 크롭 여유 비율
TARGET_ID = 0  # 예측/평가할 기본 차량 ID
USE_AMP = True  # CUDA 학습 시 자동 혼합 정밀도(AMP) 사용 여부
USE_CHANNELS_LAST = True  # CUDA 사용 시 3D 텐서 channels_last 메모리 포맷 사용 여부

# ---------- 학습 전용 ----------
TRAIN_BEST_MODEL_SAVE_PATH = Path("/content/drive/MyDrive/Dataset/best_hitandrun_model.pth")  # 학습 중 가장 좋은 모델을 저장할 경로
TRAIN_BATCH_SIZE = 15  # 학습/검증 DataLoader 배치 크기
TRAIN_NUM_EPOCHS = 5  # 최대 학습 epoch 수
TRAIN_SPLIT_RATIO = 0.8  # 전체 데이터 중 학습 데이터 비율
TRAIN_EARLY_STOPPING_PATIENCE = 10  # 검증 손실 개선이 없을 때 기다릴 epoch 수

# ---------- 단일 영상 예측/CAM 출력 전용 ----------
PREDICT_WEIGHTS_PATH = Path("/content/drive/MyDrive/Dataset/best_hitandrun_model.pth")  # 단일 영상 예측에 불러올 가중치 파일 경로
PREDICT_VIDEO_PATH = Path("/content/drive/MyDrive/Dataset/Dataset/220510_LA_0001.mp4")  # 분석할 단일 영상 파일 경로
PREDICT_TXT_PATH = Path("/content/drive/MyDrive/Dataset/Dataset/220510_LA_0001.txt")  # 단일 영상에 대응하는 bbox txt 파일 경로
PREDICT_OUTPUT_DIR = Path("/content/drive/MyDrive/Dataset/Predictions/Result")  # CAM 예측 결과 영상 저장 폴더 경로
PREDICT_DIR_PATH = Path("/content/drive/MyDrive/Dataset/Predictions/Original")  # 폴더 디렉토리 단위 예측을 수행할 폴더 경로
PREDICT_INFER_BATCH_SIZE = 16  # 단일 영상 슬라이딩 윈도우 추론 배치 크기
PREDICT_WINDOW_STRIDE = 3  # 단일 영상 추론 시 슬라이딩 윈도우 이동 간격(프레임)

# ---------- 랜덤영상 정확도 예측 전용 ----------
EVAL_WEIGHTS_PATH = Path("/content/drive/MyDrive/Dataset/best_hitandrun_model.pth")  # 랜덤영상 정확도 예측에 불러올 가중치 파일 경로
EVAL_FOLDER_PATH = Path("/content/drive/MyDrive/Dataset/Dataset")  # 랜덤으로 샘플링할 영상/txt 폴더 경로
EVAL_NUM_SAMPLES = 50  # 랜덤으로 평가할 영상 수(None이면 전체 평가)
EVAL_INFER_BATCH_SIZE = 32  # 랜덤영상 정확도 예측 추론 배치 크기
EVAL_WINDOW_STRIDE = 3  # 랜덤영상 정확도 예측 시 슬라이딩 윈도우 이동 간격(프레임)

# %%
# Colab용 환경설정
# 필요한 경우 opencv 설치 (Colab에는 기본적으로 설치되어 있으나 확인용)
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
# [데이터 전처리 및 Custom Dataset 셀]

import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms

# ==========================================
# [1단계] 데이터 전처리 및 Custom Dataset
# ==========================================
class HitAndRunDataset(Dataset):
    def __init__(self, data_dir, clip_length=30, r_value=1.0, resize=(224, 224)):
        self.data_dir = data_dir
        self.clip_length = clip_length
        self.r_value = r_value
        self.resize = resize
        self.mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(3, 1, 1, 1)
        self.std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(3, 1, 1, 1)

        self.file_names = sorted(f.rsplit('.', 1)[0] for f in os.listdir(data_dir) if f.endswith('.mp4'))
        self.samples = self._build_index()

    def __len__(self):
        return len(self.samples)

    def _build_index(self):
        samples = []
        for file_name in self.file_names:
            mp4_path = os.path.join(self.data_dir, f"{file_name}.mp4")
            txt_path = os.path.join(self.data_dir, f"{file_name}.txt")
            bboxes, action = self._parse_annotation(txt_path)

            if action is not None:
                class_str = action[0]
                target_id = int(float(action[1]))
                start_f = int(float(action[2]))
            else:
                class_str = 'S'
                target_id = 0
                start_f = 0

            if target_id not in bboxes:
                target_id = next(iter(bboxes), 0)
            target_bbox = bboxes.get(target_id, [0, 0, 224, 224])
            label = 1 if class_str == 'A' else 0

            samples.append({
                'file_name': file_name,
                'mp4_path': mp4_path,
                'label': label,
                'start_f': start_f,
                'bbox': target_bbox,
            })
        return samples

    def _parse_annotation(self, txt_path):
        bboxes = {}
        action = None
        if os.path.exists(txt_path):
            with open(txt_path, 'r') as f:
                for line in f:
                    parts = line.strip().split(',')
                    if not parts or len(parts) < 2:
                        continue
                    if parts[0] == 'car' and len(parts) >= 6:
                        bboxes[int(parts[1])] = [int(parts[2]), int(parts[3]), int(parts[4]), int(parts[5])]
                    elif parts[0] in ['A', 'S']:
                        action = parts
        return bboxes, action

    def _crop_and_pad(self, frame, bbox, r):
        h, w, _ = frame.shape
        x_min, y_min, x_max, y_max = bbox

        veh_w, veh_h = (x_max - x_min) * r, (y_max - y_min) * r
        cx, cy = x_min + (x_max - x_min) // 2, y_min + (y_max - y_min) // 2

        square_size = int(max(veh_w, veh_h))
        new_x_min, new_y_min = cx - square_size // 2, cy - square_size // 2
        new_x_max, new_y_max = cx + square_size // 2, cy + square_size // 2

        pad_left, pad_top = max(0, -new_x_min), max(0, -new_y_min)
        pad_right, pad_bottom = max(0, new_x_max - w), max(0, new_y_max - h)

        valid_x_min, valid_y_min = max(0, new_x_min), max(0, new_y_min)
        valid_x_max, valid_y_max = min(w, new_x_max), min(h, new_y_max)
        cropped_frame = frame[valid_y_min:valid_y_max, valid_x_min:valid_x_max]

        if pad_left > 0 or pad_top > 0 or pad_right > 0 or pad_bottom > 0:
            cropped_frame = np.pad(
                cropped_frame,
                ((pad_top, pad_bottom), (pad_left, pad_right), (0, 0)),
                mode='constant',
                constant_values=0,
            )

        return cv2.resize(cropped_frame, self.resize, interpolation=cv2.INTER_LINEAR)

    def _frames_to_tensor(self, frames):
        arr = np.stack(frames, axis=0).astype(np.float32) / 255.0
        video_tensor = torch.from_numpy(arr).permute(3, 0, 1, 2).contiguous()
        return (video_tensor - self.mean) / self.std

    def __getitem__(self, idx):
        sample = self.samples[idx]
        cap = cv2.VideoCapture(sample['mp4_path'])
        frames = []
        cap.set(cv2.CAP_PROP_POS_FRAMES, sample['start_f'])

        for _ in range(self.clip_length):
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(self._crop_and_pad(frame, sample['bbox'], self.r_value))
        cap.release()

        while len(frames) < self.clip_length:
            frames.append(frames[-1] if frames else np.zeros((self.resize[1], self.resize[0], 3), dtype=np.uint8))

        return self._frames_to_tensor(frames), torch.tensor(sample['label'], dtype=torch.long)

# %%
# [모델 설계 셀]

# ==========================================
# [2단계] I3D 기반 3D-CNN 모델 설계
# ==========================================
class BasicConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv3d, self).__init__()
        self.conv = nn.Conv3d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm3d(out_channels)

    def forward(self, x):
        return F.relu(self.bn(self.conv(x)), inplace=True)

class InceptionModule3D(nn.Module):
    def __init__(self, in_channels, out_1x1, red_3x3, out_3x3, red_3x3_2, out_3x3_2, out_pool):
        super(InceptionModule3D, self).__init__()
        self.branch1 = BasicConv3d(in_channels, out_1x1, kernel_size=1)
        self.branch2 = nn.Sequential(BasicConv3d(in_channels, red_3x3, kernel_size=1), BasicConv3d(red_3x3, out_3x3, kernel_size=3, padding=1))
        self.branch3 = nn.Sequential(BasicConv3d(in_channels, red_3x3_2, kernel_size=1), BasicConv3d(red_3x3_2, out_3x3_2, kernel_size=3, padding=1))
        self.branch4 = nn.Sequential(nn.MaxPool3d(kernel_size=3, stride=1, padding=1), BasicConv3d(in_channels, out_pool, kernel_size=1))

    def forward(self, x):
        return torch.cat([self.branch1(x), self.branch2(x), self.branch3(x), self.branch4(x)], dim=1)

class HitAndRun3DCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(HitAndRun3DCNN, self).__init__()
        self.conv1 = BasicConv3d(3, 64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1))
        self.conv2 = BasicConv3d(64, 64, kernel_size=1)
        self.conv3 = BasicConv3d(64, 192, kernel_size=3, padding=1)
        self.maxpool2 = nn.MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1))
        self.inception1 = InceptionModule3D(192, 64, 96, 128, 16, 32, 32)
        self.inception2 = InceptionModule3D(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool3d(kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
        self.inception3 = InceptionModule3D(480, 192, 96, 208, 16, 48, 64)

        self.avg_pool = nn.AdaptiveAvgPool3d((1, 1, 1))
        self.head_conv = nn.Conv3d(512, num_classes, kernel_size=(1, 1, 1))
        self._initialize_weights()

    def forward(self, x):
        x = self.maxpool1(self.conv1(x))
        x = self.maxpool2(self.conv3(self.conv2(x)))
        x = self.maxpool3(self.inception2(self.inception1(x)))
        x = self.avg_pool(self.inception3(x))
        logits = self.head_conv(x)
        return logits.view(logits.size(0), -1)

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv3d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm3d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

# %%
# [학습 전용 셀]

# ==========================================
# [3단계] 조기 종료 및 학습 루프 실행부
# ==========================================
class EarlyStopping:
    def __init__(self, patience=10, delta=0, path='best_model.pth'):
        self.patience = patience
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'조기 종료 카운트: {self.counter} / {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if val_loss < self.val_loss_min:
            print(f'검증 손실 감소 ({self.val_loss_min:.6f} --> {val_loss:.6f}). 모델 저장 중...')
            torch.save(model.state_dict(), self.path)
            self.val_loss_min = val_loss

def _make_loader(dataset, batch_size, shuffle, device):
    num_workers = min(4, os.cpu_count() or 2)
    kwargs = {
        'batch_size': batch_size,
        'shuffle': shuffle,
        'num_workers': num_workers,
        'pin_memory': device.type == 'cuda',
    }
    if num_workers > 0:
        kwargs.update({'persistent_workers': True, 'prefetch_factor': 2})
    return DataLoader(dataset, **kwargs)

def train_model(data_dir, batch_size=15, num_epochs=5, clip_length=30, r_value=1.0, resize=(224, 224), save_path='best_model.pth', train_split_ratio=0.8, early_stopping_patience=10, use_amp=True, use_channels_last=True):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"✅ 사용 중인 디바이스: {device}")

    if device.type == 'cuda':
        torch.backends.cudnn.benchmark = True

    full_dataset = HitAndRunDataset(data_dir=data_dir, clip_length=clip_length, r_value=r_value, resize=resize)
    train_size = int(train_split_ratio * len(full_dataset))
    val_size = len(full_dataset) - train_size
    train_subset, val_subset = random_split(full_dataset, [train_size, val_size])

    train_loader = _make_loader(train_subset, batch_size=batch_size, shuffle=True, device=device)
    val_loader = _make_loader(val_subset, batch_size=batch_size, shuffle=False, device=device)

    model = HitAndRun3DCNN(num_classes=2).to(device)
    channels_last_enabled = use_channels_last and device.type == 'cuda'
    if channels_last_enabled:
        model = model.to(memory_format=torch.channels_last_3d)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.00001)
    amp_enabled = use_amp and device.type == 'cuda'
    scaler = torch.amp.GradScaler("cuda", enabled=amp_enabled)

    early_stopping = EarlyStopping(patience=early_stopping_patience, path=save_path)

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, labels in train_loader:
            inputs = inputs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
            if channels_last_enabled:
                inputs = inputs.contiguous(memory_format=torch.channels_last_3d)

            optimizer.zero_grad(set_to_none=True)
            with torch.amp.autocast("cuda", enabled=amp_enabled):
                outputs = model(inputs)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item() * inputs.size(0)

        avg_train_loss = train_loss / len(train_loader.dataset)

        model.eval()
        val_loss = 0.0
        correct = 0
        with torch.inference_mode():
            for inputs, labels in val_loader:
                inputs = inputs.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)
                if channels_last_enabled:
                    inputs = inputs.contiguous(memory_format=torch.channels_last_3d)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                preds = outputs.argmax(dim=1)
                correct += torch.sum(preds == labels)

        avg_val_loss = val_loss / len(val_loader.dataset)
        val_acc = correct.double() / len(val_loader.dataset)

        print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f} | Val Acc: {val_acc:.4f}')

        early_stopping(avg_val_loss, model)
        if early_stopping.early_stop:
            print("🛑 조기 종료 조건 충족. 학습을 중단합니다.")
            break

    model.load_state_dict(torch.load(save_path, map_location=device))
    return model

# --- 실제 학습을 시작하는 부분 ---
if os.path.exists(DATA_DIR):
    print(f"데이터 디렉토리 확인 완료: {DATA_DIR}. 학습을 시작합니다!")
    trained_model = train_model(
        data_dir=DATA_DIR,
        batch_size=TRAIN_BATCH_SIZE,
        num_epochs=TRAIN_NUM_EPOCHS,
        clip_length=CLIP_LENGTH,
        r_value=R_VALUE,
        resize=RESIZE,
        save_path=TRAIN_BEST_MODEL_SAVE_PATH,
        train_split_ratio=TRAIN_SPLIT_RATIO,
        early_stopping_patience=TRAIN_EARLY_STOPPING_PATIENCE,
        use_amp=USE_AMP,
        use_channels_last=USE_CHANNELS_LAST,
    )
else:
    print(f"⚠️ 데이터 폴더를 찾을 수 없습니다: {DATA_DIR}")

# %%
# [단일 영상 예측/CAM 출력 전용 셀]

import cv2
import torch
import numpy as np
import torchvision.transforms as transforms
import torch.nn.functional as F
import os

# ==========================================
# 1. CAM 출력을 위한 특징 맵 추출기 (Hook)
# ==========================================
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

def frames_to_video_tensor(frames):
    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(3, 1, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(3, 1, 1, 1)
    arr = np.stack(frames, axis=0).astype(np.float32) / 255.0
    tensor = torch.from_numpy(arr).permute(3, 0, 1, 2).contiguous()
    return (tensor - mean) / std

# ==========================================
# 2. 정사각형 패딩 + 라벨 프리 + 전체 화면 CAM 예측 함수
# ==========================================
def predict_hit_and_run_final(model, video_path, txt_path, target_id=0, r_value=1.0, resize=(224, 224), output_dir=None, infer_batch_size=16, window_stride=3):
    video_path = str(video_path)
    txt_path = str(txt_path)
    if output_dir is None:
        output_dir = PREDICT_OUTPUT_DIR
    output_dir = Path(output_dir)
    print(f"[{os.path.basename(video_path)}] 전체 화면 분석 시작...")
    device = next(model.parameters()).device
    model.eval()
    window_stride = max(1, int(window_stride))

    if device.type == 'cuda':
        torch.backends.cudnn.benchmark = True

    handle = model.inception3.register_forward_hook(get_activation('inception3'))

    try:
        bboxes = {}
        if not os.path.exists(txt_path):
            print(f"⚠️ 텍스트 파일을 찾을 수 없습니다: {txt_path}")
            return

        with open(txt_path, 'r') as f:
            for line in f:
                parts = line.strip().split(',')
                if len(parts) >= 6 and parts[0] == 'car':
                    bboxes[int(parts[1])] = [int(parts[2]), int(parts[3]), int(parts[4]), int(parts[5])]

        if target_id not in bboxes:
            print(f"⚠️ ID {target_id}번 차량의 좌표가 없습니다. 존재하는 ID: {list(bboxes.keys())}")
            return

        target_bbox = bboxes[target_id]

        def crop_square_and_pad(frame, bbox, r):
            h, w, _ = frame.shape
            x_min, y_min, x_max, y_max = bbox
            vw, vh = (x_max - x_min) * r, (y_max - y_min) * r
            cx, cy = x_min + (x_max - x_min) // 2, y_min + (y_max - y_min) // 2
            side = int(max(vw, vh))
            nx1, ny1 = cx - side // 2, cy - side // 2
            nx2, ny2 = cx + side // 2, cy + side // 2
            v_x1, v_y1 = max(0, nx1), max(0, ny1)
            v_x2, v_y2 = min(w, nx2), min(h, ny2)
            p_l, p_t = max(0, -nx1), max(0, -ny1)
            p_r, p_b = max(0, nx2 - w), max(0, ny2 - h)
            cropped = frame[v_y1:v_y2, v_x1:v_x2]
            if p_l > 0 or p_t > 0 or p_r > 0 or p_b > 0:
                cropped = np.pad(cropped, ((p_t, p_b), (p_l, p_r), (0, 0)), mode='constant')
            return cv2.resize(cropped, resize, interpolation=cv2.INTER_LINEAR), (nx1, ny1, nx2, ny2)

        cap = cv2.VideoCapture(video_path)
        original_full_frames = []
        processed_frames = []

        ret, first_frame = cap.read()
        if not ret:
            return
        _, (rx1, ry1, rx2, ry2) = crop_square_and_pad(first_frame, target_bbox, r_value)
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            original_full_frames.append(frame_rgb)
            processed, _ = crop_square_and_pad(frame_rgb, target_bbox, r_value)
            processed_frames.append(processed)
        cap.release()

        if not processed_frames:
            return

        while len(processed_frames) < 30:
            processed_frames.append(processed_frames[-1])
            original_full_frames.append(original_full_frames[-1])

        full_video_tensor = frames_to_video_tensor(processed_frames)
        orig_h, orig_w = original_full_frames[0].shape[:2]

        out_path = output_dir / f'final_{os.path.basename(video_path)}'
        os.makedirs(out_path.parent, exist_ok=True)
        out_video = cv2.VideoWriter(str(out_path), cv2.VideoWriter_fourcc(*'mp4v'), 30.0, (orig_w, orig_h))

        v_nx1, v_ny1 = max(0, rx1), max(0, ry1)
        v_nx2, v_ny2 = min(orig_w, rx2), min(orig_h, ry2)

        for i in range(min(29, len(original_full_frames))):
            final_frame = cv2.cvtColor(original_full_frames[i], cv2.COLOR_RGB2BGR)
            cv2.rectangle(final_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
            out_video.write(final_frame)
        next_frame_to_write = min(29, len(original_full_frames))

        print(f"🔍 배치 슬라이딩 윈도우 추론 및 히트맵 생성 중... (stride={window_stride})")
        num_windows = full_video_tensor.size(1) - 29
        window_starts = list(range(0, num_windows, window_stride))
        with torch.inference_mode():
            for batch_start in range(0, len(window_starts), infer_batch_size):
                batch_window_starts = window_starts[batch_start:batch_start + infer_batch_size]
                clips = torch.stack([full_video_tensor[:, i:i+30, :, :] for i in batch_window_starts])
                clips = clips.to(device, non_blocking=True)
                if device.type == 'cuda':
                    clips = clips.contiguous(memory_format=torch.channels_last_3d)

                outputs = model(clips)
                probs = F.softmax(outputs, dim=1)
                pred_classes = outputs.argmax(dim=1)
                feat_maps = activation['inception3']

                for offset, window_idx in enumerate(batch_window_starts):
                    frame_idx = window_idx + 29
                    pred_class = int(pred_classes[offset].item())
                    conf = probs[offset, pred_class].item() * 100

                    feat_map = feat_maps[offset]
                    weight = model.head_conv.weight[pred_class]
                    cam = torch.sum(weight * feat_map, dim=0)
                    cam = F.relu(cam)
                    cam_2d = torch.mean(cam, dim=0).cpu().numpy()
                    cam_2d = (cam_2d - cam_2d.min()) / (cam_2d.max() - cam_2d.min() + 1e-8)

                    heatmap = cv2.applyColorMap(np.uint8(255 * cam_2d), cv2.COLORMAP_JET)
                    heatmap = cv2.resize(heatmap, (rx2-rx1, ry2-ry1))
                    heatmap_valid = heatmap[v_ny1-ry1:(v_ny1-ry1)+(v_ny2-v_ny1), v_nx1-rx1:(v_nx1-rx1)+(v_nx2-v_nx1)]

                    for skipped_idx in range(next_frame_to_write, frame_idx):
                        skipped_frame = cv2.cvtColor(original_full_frames[skipped_idx], cv2.COLOR_RGB2BGR)
                        cv2.rectangle(skipped_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
                        out_video.write(skipped_frame)

                    final_frame = cv2.cvtColor(original_full_frames[frame_idx], cv2.COLOR_RGB2BGR)
                    roi = final_frame[v_ny1:v_ny2, v_nx1:v_nx2]

                    if pred_class == 1:
                        final_frame[v_ny1:v_ny2, v_nx1:v_nx2] = cv2.addWeighted(roi, 0.6, heatmap_valid, 0.4, 0)
                        color, label_text = (0, 0, 255), f"Accident ({conf:.1f}%)"
                    else:
                        color, label_text = (0, 255, 0), f"Normal ({conf:.1f}%)"

                    cv2.rectangle(final_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), color, 3)
                    cv2.putText(final_frame, label_text, (50, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, color, 3)
                    out_video.write(final_frame)
                    next_frame_to_write = frame_idx + 1

        for skipped_idx in range(next_frame_to_write, len(original_full_frames)):
            skipped_frame = cv2.cvtColor(original_full_frames[skipped_idx], cv2.COLOR_RGB2BGR)
            cv2.rectangle(skipped_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
            out_video.write(skipped_frame)

        out_video.release()
        print(f"✨ 분석 완료! 결과 파일: {out_path}")
    finally:
        handle.remove()

# ==========================================
# 3. [핵심] 가중치 불러오기 및 실행부
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loaded_model = HitAndRun3DCNN(num_classes=MODEL_NUM_CLASSES).to(device)
if device.type == 'cuda':
    loaded_model = loaded_model.to(memory_format=torch.channels_last_3d)

try:
    loaded_model.load_state_dict(torch.load(PREDICT_WEIGHTS_PATH, map_location=device))
    print("✅ 성공적으로 학습된 가중치(best_hitandrun_model.pth)를 불러왔습니다!")

    predict_hit_and_run_final(
        loaded_model,
        PREDICT_VIDEO_PATH,
        PREDICT_TXT_PATH,
        target_id=TARGET_ID,
        r_value=R_VALUE,
        resize=RESIZE,
        output_dir=PREDICT_OUTPUT_DIR,
        infer_batch_size=PREDICT_INFER_BATCH_SIZE,
        window_stride=PREDICT_WINDOW_STRIDE,
    )

except FileNotFoundError:
    print(f"⚠️ 에러: {PREDICT_WEIGHTS_PATH} 경로에 가중치 파일이 없습니다.")
    print("경로가 정확한지 확인하시거나, 먼저 학습 코드를 실행하여 가중치 파일을 생성해 주세요.")

# %%
import cv2
import torch
import numpy as np
import torchvision.transforms as transforms
import torch.nn.functional as F
import os
from pathlib import Path

# ==========================================
# 1. CAM 출력을 위한 특징 맵 추출기 및 유틸 함수 (정의 누락 방지용)
# ==========================================
if 'get_activation' not in globals():
    activation = {}
    def get_activation(name):
        def hook(model, input, output):
            activation[name] = output.detach()
        return hook

if 'frames_to_video_tensor' not in globals():
    def frames_to_video_tensor(frames):
        mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(3, 1, 1, 1)
        std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(3, 1, 1, 1)
        arr = np.stack(frames, axis=0).astype(np.float32) / 255.0
        tensor = torch.from_numpy(arr).permute(3, 0, 1, 2).contiguous()
        return (tensor - mean) / std

# ==========================================
# 2. 정사각형 패딩 + 라벨 프리 + 전체 화면 CAM 예측 함수 (정의 누락 방지용)
# ==========================================
if 'predict_hit_and_run_final' not in globals():
    activation = {}
    def get_activation(name):
        def hook(model, input, output):
            activation[name] = output.detach()
        return hook

    def predict_hit_and_run_final(model, video_path, txt_path, target_id=0, r_value=1.0, resize=(224, 224), output_dir=None, infer_batch_size=16, window_stride=3):
        video_path = str(video_path)
        txt_path = str(txt_path)
        if output_dir is None:
            output_dir = PREDICT_OUTPUT_DIR
        output_dir = Path(output_dir)
        print(f"[{os.path.basename(video_path)}] 전체 화면 분석 시작...")
        device = next(model.parameters()).device
        model.eval()
        window_stride = max(1, int(window_stride))

        if device.type == 'cuda':
            torch.backends.cudnn.benchmark = True

        handle = model.inception3.register_forward_hook(get_activation('inception3'))

        try:
            bboxes = {}
            if not os.path.exists(txt_path):
                print(f"⚠️ 텍스트 파일을 찾을 수 없습니다: {txt_path}")
                return

            with open(txt_path, 'r') as f:
                for line in f:
                    parts = line.strip().split(',')
                    if len(parts) >= 6 and parts[0] == 'car':
                        bboxes[int(parts[1])] = [int(parts[2]), int(parts[3]), int(parts[4]), int(parts[5])]

            if target_id not in bboxes:
                print(f"⚠️ ID {target_id}번 차량의 좌표가 없습니다. 존재하는 ID: {list(bboxes.keys())}")
                return

            target_bbox = bboxes[target_id]

            def crop_square_and_pad(frame, bbox, r):
                h, w, _ = frame.shape
                x_min, y_min, x_max, y_max = bbox
                vw, vh = (x_max - x_min) * r, (y_max - y_min) * r
                cx, cy = x_min + (x_max - x_min) // 2, y_min + (y_max - y_min) // 2
                side = int(max(vw, vh))
                nx1, ny1 = cx - side // 2, cy - side // 2
                nx2, ny2 = cx + side // 2, cy + side // 2
                v_x1, v_y1 = max(0, nx1), max(0, ny1)
                v_x2, v_y2 = min(w, nx2), min(h, ny2)
                p_l, p_t = max(0, -nx1), max(0, -ny1)
                p_r, p_b = max(0, nx2 - w), max(0, ny2 - h)
                cropped = frame[v_y1:v_y2, v_x1:v_x2]
                if p_l > 0 or p_t > 0 or p_r > 0 or p_b > 0:
                    cropped = np.pad(cropped, ((p_t, p_b), (p_l, p_r), (0, 0)), mode='constant')
                return cv2.resize(cropped, resize, interpolation=cv2.INTER_LINEAR), (nx1, ny1, nx2, ny2)

            cap = cv2.VideoCapture(video_path)
            original_full_frames = []
            processed_frames = []

            ret, first_frame = cap.read()
            if not ret:
                return
            _, (rx1, ry1, rx2, ry2) = crop_square_and_pad(first_frame, target_bbox, r_value)
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                original_full_frames.append(frame_rgb)
                processed, _ = crop_square_and_pad(frame_rgb, target_bbox, r_value)
                processed_frames.append(processed)
            cap.release()

            if not processed_frames:
                return

            while len(processed_frames) < 30:
                processed_frames.append(processed_frames[-1] if frames else np.zeros((resize[1], resize[0], 3), dtype=np.uint8))

            full_video_tensor = frames_to_video_tensor(processed_frames)
            orig_h, orig_w = original_full_frames[0].shape[:2]

            out_path = output_dir / f'final_{os.path.basename(video_path)}'
            os.makedirs(out_path.parent, exist_ok=True)
            out_video = cv2.VideoWriter(str(out_path), cv2.VideoWriter_fourcc(*'mp4v'), 30.0, (orig_w, orig_h))

            v_nx1, v_ny1 = max(0, rx1), max(0, ry1)
            v_nx2, v_ny2 = min(orig_w, rx2), min(orig_h, ry2)

            for i in range(min(29, len(original_full_frames))):
                final_frame = cv2.cvtColor(original_full_frames[i], cv2.COLOR_RGB2BGR)
                cv2.rectangle(final_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
                out_video.write(final_frame)
            next_frame_to_write = min(29, len(original_full_frames))

            print(f"🔍 배치 슬라이딩 윈도우 추론 및 히트맵 생성 중... (stride={window_stride})")
            num_windows = full_video_tensor.size(1) - 29
            window_starts = list(range(0, num_windows, window_stride))
            with torch.inference_mode():
                for batch_start in range(0, len(window_starts), infer_batch_size):
                    batch_window_starts = window_starts[batch_start:batch_start + infer_batch_size]
                    clips = torch.stack([full_video_tensor[:, i:i+30, :, :] for i in batch_window_starts])
                    clips = clips.to(device, non_blocking=True)
                    if device.type == 'cuda':
                        clips = clips.contiguous(memory_format=torch.channels_last_3d)

                    outputs = model(clips)
                    probs = F.softmax(outputs, dim=1)
                    pred_classes = outputs.argmax(dim=1)
                    feat_maps = activation['inception3']

                    for offset, window_idx in enumerate(batch_window_starts):
                        frame_idx = window_idx + 29
                        pred_class = int(pred_classes[offset].item())
                        conf = probs[offset, pred_class].item() * 100

                        feat_map = feat_maps[offset]
                        weight = model.head_conv.weight[pred_class]
                        cam = torch.sum(weight * feat_map, dim=0)
                        cam = F.relu(cam)
                        cam_2d = torch.mean(cam, dim=0).cpu().numpy()
                        cam_2d = (cam_2d - cam_2d.min()) / (cam_2d.max() - cam_2d.min() + 1e-8)

                        heatmap = cv2.applyColorMap(np.uint8(255 * cam_2d), cv2.COLORMAP_JET)
                        heatmap = cv2.resize(heatmap, (rx2-rx1, ry2-ry1))
                        heatmap_valid = heatmap[v_ny1-ry1:(v_ny1-ry1)+(v_ny2-v_ny1), v_nx1-rx1:(v_nx1-rx1)+(v_nx2-v_nx1)]

                        for skipped_idx in range(next_frame_to_write, frame_idx):
                            skipped_frame = cv2.cvtColor(original_full_frames[skipped_idx], cv2.COLOR_RGB2BGR)
                            cv2.rectangle(skipped_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
                            out_video.write(skipped_frame)

                        final_frame = cv2.cvtColor(original_full_frames[frame_idx], cv2.COLOR_RGB2BGR)
                        roi = final_frame[v_ny1:v_ny2, v_nx1:v_nx2]

                        if pred_class == 1:
                            final_frame[v_ny1:v_ny2, v_nx1:v_nx2] = cv2.addWeighted(roi, 0.6, heatmap_valid, 0.4, 0)
                            color, label_text = (0, 0, 255), f"Accident ({conf:.1f}%)"
                        else:
                            color, label_text = (0, 255, 0), f"Normal ({conf:.1f}%)"

                        cv2.rectangle(final_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), color, 3)
                        cv2.putText(final_frame, label_text, (50, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, color, 3)
                        out_video.write(final_frame)
                        next_frame_to_write = frame_idx + 1

            for skipped_idx in range(next_frame_to_write, len(original_full_frames)):
                skipped_frame = cv2.cvtColor(original_full_frames[skipped_idx], cv2.COLOR_RGB2BGR)
                cv2.rectangle(skipped_frame, (v_nx1, v_ny1), (v_nx2, v_ny2), (0, 255, 0), 2)
                out_video.write(skipped_frame)

            out_video.release()
            print(f"✨ 분석 완료! 결과 파일: {out_path}")
        finally:
            handle.remove()

# ==========================================
# 3. 폴더 단위 일괄 예측 실행 루프
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loaded_model = HitAndRun3DCNN(num_classes=MODEL_NUM_CLASSES).to(device)
if device.type == 'cuda':
    loaded_model = loaded_model.to(memory_format=torch.channels_last_3d)

try:
    loaded_model.load_state_dict(torch.load(PREDICT_WEIGHTS_PATH, map_location=device))
    print("✅ 성공적으로 학습된 가중치(best_hitandrun_model.pth)를 불러왔습니다!")

    # 디렉토리 존재 여부 확인
    if not PREDICT_DIR_PATH or not Path(PREDICT_DIR_PATH).exists():
        print("⚠️ 에러: PREDICT_DIR_PATH를 설정해 주세요. 현재 비어있거나 존재하지 않는 경로입니다.")
    else:
        predict_dir = Path(PREDICT_DIR_PATH)
        video_files = sorted(list(predict_dir.glob("*.mp4")))

        if not video_files:
            print(f"⚠️ {predict_dir} 폴더 내에 mp4 파일이 존재하지 않습니다.")
        else:
            print(f"📂 총 {len(video_files)}개의 영상을 발견했습니다. 순차적으로 분석을 진행합니다.")

            for idx, video_path in enumerate(video_files):
                txt_path = video_path.with_suffix('.txt')
                if not txt_path.exists():
                    print(f" [{idx+1}/{len(video_files)}] ⚠️ 대응하는 텍스트 파일을 찾을 수 없습니다: {txt_path.name} (건너뜀)")
                    continue

                print(f"\n🎥 [{idx+1}/{len(video_files)}] {video_path.name} 분석 중...")
                try:
                    predict_hit_and_run_final(
                        loaded_model,
                        video_path,
                        txt_path,
                        target_id=TARGET_ID,
                        r_value=R_VALUE,
                        resize=RESIZE,
                        output_dir=PREDICT_OUTPUT_DIR,
                        infer_batch_size=PREDICT_INFER_BATCH_SIZE,
                        window_stride=PREDICT_WINDOW_STRIDE,
                    )
                except Exception as e:
                    print(f"❌ 분석 오류 ({video_path.name}): {e}")

except FileNotFoundError:
    print(f"⚠️ 에러: {PREDICT_WEIGHTS_PATH} 경로에 가중치 파일이 없습니다.")
    print("경로가 정확한지 확인하시거나, 먼저 학습 코드를 실행하여 가중치 파일을 생성해 주세요.")
# Out:
# ✅ 성공적으로 학습된 가중치(best_hitandrun_model.pth)를 불러왔습니다!
# 📂 총 832개의 영상을 발견했습니다. 순차적으로 분석을 진행합니다.
#
# 🎥 [1/832] 220510_LA_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [2/832] 220510_LA_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [3/832] 220510_LA_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [4/832] 220510_LA_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [5/832] 220510_LA_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [6/832] 220510_LA_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [7/832] 220510_LA_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [8/832] 220510_LA_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [9/832] 220510_LA_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [10/832] 220510_LA_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [11/832] 220510_LA_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [12/832] 220510_LA_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [13/832] 220510_LA_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [14/832] 220510_LA_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [15/832] 220510_LA_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [16/832] 220510_LA_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [17/832] 220510_LA_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [18/832] 220510_LA_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [19/832] 220510_LA_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [20/832] 220510_LA_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [21/832] 220510_LA_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [22/832] 220510_LA_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [23/832] 220510_LA_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [24/832] 220510_LA_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [25/832] 220510_LA_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [26/832] 220510_LA_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [27/832] 220510_LA_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [28/832] 220510_LA_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [29/832] 220510_LA_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [30/832] 220510_LA_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [31/832] 220510_LA_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [32/832] 220510_LA_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [33/832] 220510_LA_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [34/832] 220510_LA_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [35/832] 220510_LA_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [36/832] 220510_LA_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [37/832] 220510_LA_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [38/832] 220510_LA_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [39/832] 220510_LA_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [40/832] 220510_LA_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [41/832] 220510_LA_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [42/832] 220510_LA_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [43/832] 220510_LA_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [44/832] 220510_LA_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [45/832] 220510_LA_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [46/832] 220510_LA_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [47/832] 220510_LA_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [48/832] 220510_LA_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [49/832] 220510_LA_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [50/832] 220510_LA_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [51/832] 220510_LA_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [52/832] 220510_LA_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [53/832] 220510_LA_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [54/832] 220510_LA_0053.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0053.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [55/832] 220510_LA_0054.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0054.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [56/832] 220510_LA_0055.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0055.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [57/832] 220510_LA_0056.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0056.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [58/832] 220510_LA_0057.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0057.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [59/832] 220510_LA_0058.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0058.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [60/832] 220510_LA_0059.mp4 분석 중...
# ❌ 분석 오류 (220510_LA_0059.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [61/832] 220510_LS_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [62/832] 220510_LS_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [63/832] 220510_LS_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [64/832] 220510_LS_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [65/832] 220510_LS_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [66/832] 220510_LS_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [67/832] 220510_LS_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [68/832] 220510_LS_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [69/832] 220510_LS_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [70/832] 220510_LS_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [71/832] 220510_LS_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [72/832] 220510_LS_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [73/832] 220510_LS_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [74/832] 220510_LS_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [75/832] 220510_LS_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [76/832] 220510_LS_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [77/832] 220510_LS_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [78/832] 220510_LS_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [79/832] 220510_LS_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [80/832] 220510_LS_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [81/832] 220510_LS_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [82/832] 220510_LS_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [83/832] 220510_LS_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [84/832] 220510_LS_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [85/832] 220510_LS_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [86/832] 220510_LS_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [87/832] 220510_LS_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [88/832] 220510_LS_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [89/832] 220510_LS_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [90/832] 220510_LS_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [91/832] 220510_LS_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [92/832] 220510_LS_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [93/832] 220510_LS_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [94/832] 220510_LS_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [95/832] 220510_LS_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [96/832] 220510_LS_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [97/832] 220510_LS_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [98/832] 220510_LS_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [99/832] 220510_LS_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [100/832] 220510_LS_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [101/832] 220510_LS_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [102/832] 220510_LS_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [103/832] 220510_LS_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [104/832] 220510_LS_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [105/832] 220510_LS_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [106/832] 220510_LS_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [107/832] 220510_LS_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [108/832] 220510_LS_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [109/832] 220510_LS_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [110/832] 220510_LS_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [111/832] 220510_LS_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [112/832] 220510_LS_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [113/832] 220510_LS_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_LS_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [114/832] 220510_LV_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [115/832] 220510_LV_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [116/832] 220510_LV_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [117/832] 220510_LV_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [118/832] 220510_LV_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [119/832] 220510_LV_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [120/832] 220510_LV_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [121/832] 220510_LV_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [122/832] 220510_LV_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [123/832] 220510_LV_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [124/832] 220510_LV_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [125/832] 220510_LV_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [126/832] 220510_LV_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [127/832] 220510_LV_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [128/832] 220510_LV_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [129/832] 220510_LV_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [130/832] 220510_LV_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [131/832] 220510_LV_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [132/832] 220510_LV_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [133/832] 220510_LV_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [134/832] 220510_LV_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [135/832] 220510_LV_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [136/832] 220510_LV_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [137/832] 220510_LV_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [138/832] 220510_LV_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [139/832] 220510_LV_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [140/832] 220510_LV_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [141/832] 220510_LV_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [142/832] 220510_LV_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [143/832] 220510_LV_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [144/832] 220510_LV_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [145/832] 220510_LV_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [146/832] 220510_LV_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [147/832] 220510_LV_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [148/832] 220510_LV_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [149/832] 220510_LV_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [150/832] 220510_LV_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [151/832] 220510_LV_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [152/832] 220510_LV_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [153/832] 220510_LV_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [154/832] 220510_LV_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [155/832] 220510_LV_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [156/832] 220510_LV_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [157/832] 220510_LV_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [158/832] 220510_LV_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [159/832] 220510_LV_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [160/832] 220510_LV_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [161/832] 220510_LV_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [162/832] 220510_LV_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [163/832] 220510_LV_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [164/832] 220510_LV_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [165/832] 220510_LV_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [166/832] 220510_LV_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [167/832] 220510_LV_0053.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0053.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [168/832] 220510_LV_0054.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0054.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [169/832] 220510_LV_0055.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0055.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [170/832] 220510_LV_0056.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0056.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [171/832] 220510_LV_0057.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0057.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [172/832] 220510_LV_0058.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0058.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [173/832] 220510_LV_0059.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0059.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [174/832] 220510_LV_0060.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0060.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [175/832] 220510_LV_0061.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0061.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [176/832] 220510_LV_0062.mp4 분석 중...
# ❌ 분석 오류 (220510_LV_0062.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [177/832] 220510_LW_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [178/832] 220510_LW_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [179/832] 220510_LW_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [180/832] 220510_LW_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [181/832] 220510_LW_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [182/832] 220510_LW_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [183/832] 220510_LW_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [184/832] 220510_LW_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [185/832] 220510_LW_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [186/832] 220510_LW_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [187/832] 220510_LW_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [188/832] 220510_LW_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [189/832] 220510_LW_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [190/832] 220510_LW_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [191/832] 220510_LW_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [192/832] 220510_LW_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [193/832] 220510_LW_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [194/832] 220510_LW_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [195/832] 220510_LW_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [196/832] 220510_LW_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [197/832] 220510_LW_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [198/832] 220510_LW_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [199/832] 220510_LW_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [200/832] 220510_LW_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [201/832] 220510_LW_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [202/832] 220510_LW_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [203/832] 220510_LW_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [204/832] 220510_LW_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [205/832] 220510_LW_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [206/832] 220510_LW_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [207/832] 220510_LW_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [208/832] 220510_LW_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [209/832] 220510_LW_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [210/832] 220510_LW_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [211/832] 220510_LW_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [212/832] 220510_LW_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [213/832] 220510_LW_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [214/832] 220510_LW_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [215/832] 220510_LW_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [216/832] 220510_LW_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [217/832] 220510_LW_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [218/832] 220510_LW_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [219/832] 220510_LW_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [220/832] 220510_LW_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [221/832] 220510_LW_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [222/832] 220510_LW_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [223/832] 220510_LW_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [224/832] 220510_LW_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [225/832] 220510_LW_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [226/832] 220510_LW_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [227/832] 220510_LW_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [228/832] 220510_LW_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [229/832] 220510_LW_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [230/832] 220510_LW_0053.mp4 분석 중...
# ❌ 분석 오류 (220510_LW_0053.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [231/832] 220510_NA_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [232/832] 220510_NA_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [233/832] 220510_NA_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [234/832] 220510_NA_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [235/832] 220510_NA_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [236/832] 220510_NA_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [237/832] 220510_NA_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [238/832] 220510_NA_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [239/832] 220510_NA_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [240/832] 220510_NA_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [241/832] 220510_NA_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [242/832] 220510_NA_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [243/832] 220510_NA_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [244/832] 220510_NA_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [245/832] 220510_NA_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [246/832] 220510_NA_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [247/832] 220510_NA_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [248/832] 220510_NA_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [249/832] 220510_NA_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [250/832] 220510_NA_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [251/832] 220510_NA_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [252/832] 220510_NA_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [253/832] 220510_NA_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [254/832] 220510_NA_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [255/832] 220510_NA_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [256/832] 220510_NA_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [257/832] 220510_NA_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [258/832] 220510_NA_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [259/832] 220510_NA_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [260/832] 220510_NA_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [261/832] 220510_NA_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [262/832] 220510_NA_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [263/832] 220510_NA_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [264/832] 220510_NA_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [265/832] 220510_NA_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [266/832] 220510_NA_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [267/832] 220510_NA_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [268/832] 220510_NA_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [269/832] 220510_NA_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [270/832] 220510_NA_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [271/832] 220510_NA_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [272/832] 220510_NA_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [273/832] 220510_NA_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [274/832] 220510_NA_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [275/832] 220510_NA_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [276/832] 220510_NA_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [277/832] 220510_NA_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [278/832] 220510_NA_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_NA_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [279/832] 220510_NS_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [280/832] 220510_NS_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [281/832] 220510_NS_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [282/832] 220510_NS_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [283/832] 220510_NS_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [284/832] 220510_NS_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [285/832] 220510_NS_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [286/832] 220510_NS_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [287/832] 220510_NS_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [288/832] 220510_NS_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [289/832] 220510_NS_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [290/832] 220510_NS_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [291/832] 220510_NS_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [292/832] 220510_NS_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [293/832] 220510_NS_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [294/832] 220510_NS_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [295/832] 220510_NS_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [296/832] 220510_NS_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [297/832] 220510_NS_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [298/832] 220510_NS_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [299/832] 220510_NS_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [300/832] 220510_NS_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [301/832] 220510_NS_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [302/832] 220510_NS_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [303/832] 220510_NS_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [304/832] 220510_NS_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [305/832] 220510_NS_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [306/832] 220510_NS_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [307/832] 220510_NS_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [308/832] 220510_NS_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [309/832] 220510_NS_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [310/832] 220510_NS_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [311/832] 220510_NS_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [312/832] 220510_NS_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [313/832] 220510_NS_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [314/832] 220510_NS_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [315/832] 220510_NS_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [316/832] 220510_NS_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [317/832] 220510_NS_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [318/832] 220510_NS_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [319/832] 220510_NS_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [320/832] 220510_NS_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [321/832] 220510_NS_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [322/832] 220510_NS_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [323/832] 220510_NS_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [324/832] 220510_NS_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [325/832] 220510_NS_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [326/832] 220510_NS_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [327/832] 220510_NS_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [328/832] 220510_NS_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [329/832] 220510_NS_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [330/832] 220510_NS_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [331/832] 220510_NS_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_NS_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [332/832] 220510_NV_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [333/832] 220510_NV_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [334/832] 220510_NV_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [335/832] 220510_NV_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [336/832] 220510_NV_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [337/832] 220510_NV_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [338/832] 220510_NV_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [339/832] 220510_NV_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [340/832] 220510_NV_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [341/832] 220510_NV_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [342/832] 220510_NV_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [343/832] 220510_NV_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [344/832] 220510_NV_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [345/832] 220510_NV_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [346/832] 220510_NV_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [347/832] 220510_NV_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [348/832] 220510_NV_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [349/832] 220510_NV_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [350/832] 220510_NV_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [351/832] 220510_NV_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [352/832] 220510_NV_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [353/832] 220510_NV_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [354/832] 220510_NV_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [355/832] 220510_NV_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [356/832] 220510_NV_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [357/832] 220510_NV_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [358/832] 220510_NV_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [359/832] 220510_NV_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [360/832] 220510_NV_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [361/832] 220510_NV_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [362/832] 220510_NV_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [363/832] 220510_NV_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [364/832] 220510_NV_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [365/832] 220510_NV_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [366/832] 220510_NV_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [367/832] 220510_NV_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [368/832] 220510_NV_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [369/832] 220510_NV_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [370/832] 220510_NV_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_NV_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [371/832] 220510_NW_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [372/832] 220510_NW_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [373/832] 220510_NW_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [374/832] 220510_NW_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [375/832] 220510_NW_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [376/832] 220510_NW_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [377/832] 220510_NW_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [378/832] 220510_NW_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [379/832] 220510_NW_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [380/832] 220510_NW_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [381/832] 220510_NW_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [382/832] 220510_NW_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [383/832] 220510_NW_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [384/832] 220510_NW_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [385/832] 220510_NW_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [386/832] 220510_NW_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [387/832] 220510_NW_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [388/832] 220510_NW_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [389/832] 220510_NW_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [390/832] 220510_NW_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [391/832] 220510_NW_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [392/832] 220510_NW_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [393/832] 220510_NW_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [394/832] 220510_NW_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [395/832] 220510_NW_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [396/832] 220510_NW_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [397/832] 220510_NW_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [398/832] 220510_NW_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [399/832] 220510_NW_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [400/832] 220510_NW_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [401/832] 220510_NW_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [402/832] 220510_NW_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [403/832] 220510_NW_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [404/832] 220510_NW_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [405/832] 220510_NW_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [406/832] 220510_NW_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_NW_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [407/832] 220510_NW_0036.mp4 분석 중...
# ...
#
# 🎥 [698/832] 220510_SS_0055.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0055.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [699/832] 220510_SS_0056.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0056.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [700/832] 220510_SS_0057.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0057.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [701/832] 220510_SS_0058.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0058.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [702/832] 220510_SS_0059.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0059.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [703/832] 220510_SS_0060.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0060.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [704/832] 220510_SS_0061.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0061.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [705/832] 220510_SS_0062.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0062.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [706/832] 220510_SS_0063.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0063.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [707/832] 220510_SS_0064.mp4 분석 중...
# ❌ 분석 오류 (220510_SS_0064.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [708/832] 220510_SV_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [709/832] 220510_SV_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [710/832] 220510_SV_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [711/832] 220510_SV_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [712/832] 220510_SV_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [713/832] 220510_SV_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [714/832] 220510_SV_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [715/832] 220510_SV_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [716/832] 220510_SV_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [717/832] 220510_SV_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [718/832] 220510_SV_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [719/832] 220510_SV_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [720/832] 220510_SV_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [721/832] 220510_SV_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [722/832] 220510_SV_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [723/832] 220510_SV_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [724/832] 220510_SV_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [725/832] 220510_SV_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [726/832] 220510_SV_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [727/832] 220510_SV_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [728/832] 220510_SV_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [729/832] 220510_SV_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [730/832] 220510_SV_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [731/832] 220510_SV_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [732/832] 220510_SV_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [733/832] 220510_SV_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [734/832] 220510_SV_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [735/832] 220510_SV_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [736/832] 220510_SV_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [737/832] 220510_SV_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [738/832] 220510_SV_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [739/832] 220510_SV_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [740/832] 220510_SV_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [741/832] 220510_SV_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [742/832] 220510_SV_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [743/832] 220510_SV_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [744/832] 220510_SV_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [745/832] 220510_SV_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [746/832] 220510_SV_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [747/832] 220510_SV_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [748/832] 220510_SV_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [749/832] 220510_SV_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [750/832] 220510_SV_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [751/832] 220510_SV_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [752/832] 220510_SV_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [753/832] 220510_SV_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [754/832] 220510_SV_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [755/832] 220510_SV_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [756/832] 220510_SV_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [757/832] 220510_SV_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [758/832] 220510_SV_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [759/832] 220510_SV_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [760/832] 220510_SV_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [761/832] 220510_SV_0053.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0053.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [762/832] 220510_SV_0054.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0054.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [763/832] 220510_SV_0055.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0055.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [764/832] 220510_SV_0056.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0056.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [765/832] 220510_SV_0057.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0057.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [766/832] 220510_SV_0058.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0058.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [767/832] 220510_SV_0059.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0059.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [768/832] 220510_SV_0060.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0060.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [769/832] 220510_SV_0061.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0061.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [770/832] 220510_SV_0062.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0062.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [771/832] 220510_SV_0063.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0063.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [772/832] 220510_SV_0064.mp4 분석 중...
# ❌ 분석 오류 (220510_SV_0064.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [773/832] 220510_SW_0000.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0000.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [774/832] 220510_SW_0001.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0001.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [775/832] 220510_SW_0002.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0002.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [776/832] 220510_SW_0003.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0003.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [777/832] 220510_SW_0004.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0004.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [778/832] 220510_SW_0005.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0005.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [779/832] 220510_SW_0006.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0006.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [780/832] 220510_SW_0007.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0007.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [781/832] 220510_SW_0008.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0008.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [782/832] 220510_SW_0009.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0009.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [783/832] 220510_SW_0010.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0010.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [784/832] 220510_SW_0011.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0011.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [785/832] 220510_SW_0012.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0012.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [786/832] 220510_SW_0013.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0013.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [787/832] 220510_SW_0014.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0014.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [788/832] 220510_SW_0015.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0015.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [789/832] 220510_SW_0016.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0016.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [790/832] 220510_SW_0017.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0017.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [791/832] 220510_SW_0018.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0018.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [792/832] 220510_SW_0019.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0019.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [793/832] 220510_SW_0020.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0020.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [794/832] 220510_SW_0021.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0021.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [795/832] 220510_SW_0022.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0022.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [796/832] 220510_SW_0023.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0023.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [797/832] 220510_SW_0024.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0024.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [798/832] 220510_SW_0025.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0025.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [799/832] 220510_SW_0026.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0026.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [800/832] 220510_SW_0027.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0027.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [801/832] 220510_SW_0028.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0028.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [802/832] 220510_SW_0029.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0029.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [803/832] 220510_SW_0030.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0030.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [804/832] 220510_SW_0031.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0031.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [805/832] 220510_SW_0032.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0032.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [806/832] 220510_SW_0033.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0033.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [807/832] 220510_SW_0034.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0034.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [808/832] 220510_SW_0035.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0035.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [809/832] 220510_SW_0036.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0036.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [810/832] 220510_SW_0037.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0037.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [811/832] 220510_SW_0038.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0038.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [812/832] 220510_SW_0039.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0039.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [813/832] 220510_SW_0040.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0040.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [814/832] 220510_SW_0041.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0041.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [815/832] 220510_SW_0042.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0042.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [816/832] 220510_SW_0043.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0043.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [817/832] 220510_SW_0044.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0044.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [818/832] 220510_SW_0045.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0045.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [819/832] 220510_SW_0046.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0046.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [820/832] 220510_SW_0047.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0047.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [821/832] 220510_SW_0048.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0048.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [822/832] 220510_SW_0049.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0049.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [823/832] 220510_SW_0050.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0050.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [824/832] 220510_SW_0051.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0051.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [825/832] 220510_SW_0052.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0052.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [826/832] 220510_SW_0053.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0053.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [827/832] 220510_SW_0054.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0054.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [828/832] 220510_SW_0055.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0055.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [829/832] 220510_SW_0056.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0056.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [830/832] 220510_SW_0057.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0057.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [831/832] 220510_SW_0058.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0058.mp4): name 'predict_hit_and_run_final' is not defined
#
# 🎥 [832/832] 220510_SW_0059.mp4 분석 중...
# ❌ 분석 오류 (220510_SW_0059.mp4): name 'predict_hit_and_run_final' is not defined

# %%
# [랜덤영상 정확도 예측 전용 셀]

import os
import cv2
import torch
import numpy as np
import torchvision.transforms as transforms
import torch.nn.functional as F
import random
from tqdm import tqdm

# ==========================================
# 1. 평가 전용 함수 정의
# ==========================================
def evaluate_folder_accuracy(model, folder_path, target_id=0, r_value=1.0, resize=(224, 224), num_samples=None, infer_batch_size=32, window_stride=3):
    print(f"📂 [{folder_path}] 폴더의 영상 평가를 준비합니다...")
    device = next(model.parameters()).device
    model.eval()
    window_stride = max(1, int(window_stride))

    if device.type == 'cuda':
        torch.backends.cudnn.benchmark = True

    mean = torch.tensor([0.485, 0.456, 0.406], dtype=torch.float32).view(3, 1, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225], dtype=torch.float32).view(3, 1, 1, 1)

    def crop_square_and_pad(frame, bbox, r):
        h, w, _ = frame.shape
        x_min, y_min, x_max, y_max = bbox
        vw, vh = (x_max - x_min) * r, (y_max - y_min) * r
        cx, cy = x_min + (x_max - x_min) // 2, y_min + (y_max - y_min) // 2
        side = int(max(vw, vh))
        nx1, ny1 = cx - side // 2, cy - side // 2
        nx2, ny2 = cx + side // 2, cy + side // 2
        v_x1, v_y1 = max(0, nx1), max(0, ny1)
        v_x2, v_y2 = min(w, nx2), min(h, ny2)
        p_l, p_t = max(0, -nx1), max(0, -ny1)
        p_r, p_b = max(0, nx2 - w), max(0, ny2 - h)
        cropped = frame[v_y1:v_y2, v_x1:v_x2]
        if p_l > 0 or p_t > 0 or p_r > 0 or p_b > 0:
            cropped = np.pad(cropped, ((p_t, p_b), (p_l, p_r), (0, 0)), mode='constant')
        return cv2.resize(cropped, resize, interpolation=cv2.INTER_LINEAR)

    def frames_to_tensor(frames):
        arr = np.stack(frames, axis=0).astype(np.float32) / 255.0
        video_tensor = torch.from_numpy(arr).permute(3, 0, 1, 2).contiguous()
        return (video_tensor - mean) / std

    all_files = os.listdir(folder_path)
    all_files_set = set(all_files)
    mp4_files = [f for f in all_files if f.endswith('.mp4')]
    valid_pairs = [mp4 for mp4 in mp4_files if f"{mp4.rsplit('.', 1)[0]}.txt" in all_files_set]

    if not valid_pairs:
        print("⚠️ 평가할 수 있는 영상-텍스트 짝이 없습니다.")
        return

    if num_samples is not None:
        actual_samples = min(num_samples, len(valid_pairs))
        selected_files = random.sample(valid_pairs, actual_samples)
        print(f"🎲 총 {len(valid_pairs)}개의 영상 쌍 중에서 {actual_samples}개를 랜덤으로 추출하여 평가합니다.")
    else:
        selected_files = valid_pairs
        print(f"전체 {len(valid_pairs)}개의 영상 쌍을 모두 평가합니다.")

    total_videos = 0
    correct_preds = 0
    wrong_list = []

    with torch.inference_mode():
        for mp4_file in tqdm(selected_files, desc="평가 진행률"):
            base_name = mp4_file.rsplit('.', 1)[0]
            video_path = os.path.join(folder_path, mp4_file)
            txt_path = os.path.join(folder_path, f"{base_name}.txt")

            parts = base_name.split('_')
            is_accident_gt = len(parts) >= 2 and len(parts[1]) == 2 and parts[1][1] == 'A'
            gt_label = 1 if is_accident_gt else 0

            bboxes = {}
            with open(txt_path, 'r') as f:
                for line in f:
                    l_parts = line.strip().split(',')
                    if len(l_parts) >= 6 and l_parts[0] == 'car':
                        bboxes[int(l_parts[1])] = [int(l_parts[2]), int(l_parts[3]), int(l_parts[4]), int(l_parts[5])]

            if target_id not in bboxes:
                if not bboxes:
                    continue
                target_bbox = next(iter(bboxes.values()))
            else:
                target_bbox = bboxes[target_id]

            cap = cv2.VideoCapture(video_path)
            frames = []
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frames.append(crop_square_and_pad(frame_rgb, target_bbox, r_value))
            cap.release()

            while len(frames) < 30:
                frames.append(frames[-1] if frames else np.zeros((resize[1], resize[0], 3), dtype=np.uint8))

            full_video_tensor = frames_to_tensor(frames)
            predicted_label = 0
            num_windows = len(frames) - 29
            window_starts = list(range(0, num_windows, window_stride))

            for batch_start in range(0, len(window_starts), infer_batch_size):
                batch_window_starts = window_starts[batch_start:batch_start + infer_batch_size]
                clips = torch.stack([full_video_tensor[:, i:i+30, :, :] for i in batch_window_starts])
                clips = clips.to(device, non_blocking=True)
                if device.type == 'cuda':
                    clips = clips.contiguous(memory_format=torch.channels_last_3d)

                outputs = model(clips)
                pred_classes = outputs.argmax(dim=1)
                if (pred_classes == 1).any().item():
                    predicted_label = 1
                    break

            total_videos += 1
            if predicted_label == gt_label:
                correct_preds += 1
            else:
                wrong_list.append({
                    "file": mp4_file,
                    "gt": "Accident(충돌)" if gt_label == 1 else "Normal(정상)",
                    "pred": "Accident(충돌)" if predicted_label == 1 else "Normal(정상)",
                })

    accuracy = (correct_preds / total_videos) * 100 if total_videos > 0 else 0
    print("\n" + "="*50)
    print("📊 [모델 성능 평가 결과]")
    print("="*50)
    print(f"총 평가 영상 수 : {total_videos} 개")
    print(f"정답 맞춘 수    : {correct_preds} 개")
    print(f"최종 Accuracy   : {accuracy:.2f}%")
    print("="*50)

    if wrong_list:
        print("\n❌ [오답 노트 (틀린 영상 리스트)]")
        for w in wrong_list:
            print(f" - {w['file']} (실제: {w['gt']}  |  모델예측: {w['pred']})")
    else:
        print("\n🎉 모든 영상을 완벽하게 맞췄습니다!")

# ==========================================
# 3. [핵심] 랜덤영상 정확도 예측 실행부
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loaded_model = HitAndRun3DCNN(num_classes=MODEL_NUM_CLASSES).to(device)
if device.type == 'cuda':
    loaded_model = loaded_model.to(memory_format=torch.channels_last_3d)

try:
    loaded_model.load_state_dict(torch.load(EVAL_WEIGHTS_PATH, map_location=device))
    print("✅ 성공적으로 학습된 모델 가중치를 불러왔습니다!")
    evaluate_folder_accuracy(
        loaded_model,
        EVAL_FOLDER_PATH,
        target_id=TARGET_ID,
        r_value=R_VALUE,
        resize=RESIZE,
        num_samples=EVAL_NUM_SAMPLES,
        infer_batch_size=EVAL_INFER_BATCH_SIZE,
        window_stride=EVAL_WINDOW_STRIDE,
    )

except FileNotFoundError:
    print(f"⚠️ 에러: {EVAL_WEIGHTS_PATH} 경로에 가중치 파일이 없습니다. 먼저 모델을 학습시켜주세요.")
